# %% [markdown]
# # Idéation sur les features

# %% [markdown]
# 1. Cosine similarity between titles / abstracts
# 2. Graphe des citations dirigé
#     > weight of existing citations
#     > clustering dans le graphe ?
# 3. "Pagerank" de chaque auteur
# 4. Ecart entre les années
# 5. Shortest path

# %% [markdown]
# # Initialisation

# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--master local[7]  --packages graphframes:graphframes:0.8.2-spark3.1-s_2.12  pyspark-shell'

import findspark
findspark.init()

import pyspark
from pyspark.sql import SparkSession

import graphframes

# %%
ss = SparkSession.builder.appName('challenge').getOrCreate()
sc = ss.sparkContext

dft = ss.read.csv("data/node_information.csv")
df_nodes = dft.toDF("id", "year", "topics", "authors", "temp1", "text")
df_nodes.createOrReplaceTempView("nodes")

dft = ss.read.option("delimiter", " ").csv("data/training_set.txt")
df_edges = dft.toDF("source", "target", "cites")
df_edges.createOrReplaceTempView("edges")
# Out:
# 22/04/08 19:15:58 WARN Utils: Your hostname, Dominique resolves to a loopback address: 127.0.1.1; using 172.22.77.94 instead (on interface eth0)
# 22/04/08 19:15:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/spark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/flo/.ivy2/cache
# The jars for the packages stored in: /home/flo/.ivy2/jars
# graphframes#graphframes added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-6568f1f5-d395-4895-88ba-efbae8b2d43a;1.0
# 	confs: [default]
# 	found graphframes#graphframes;0.8.2-spark3.1-s_2.12 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# :: resolution report :: resolve 220ms :: artifacts dl 7ms
# 	:: modules in use:
# 	graphframes#graphframes;0.8.2-spark3.1-s_2.12 from spark-packages in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   2   |   0   |   0   |   0   ||   2   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-6568f1f5-d395-4895-88ba-efbae8b2d43a
# 	confs: [default]
# 	0 artifacts copied, 2 already retrieved (0kB/7ms)
# 22/04/08 19:16:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /home/flo/dssp/15-challenge/work.ipynb Cell 5' in <cell line: 4>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/flo/dssp/15-challenge/work.ipynb#ch0000004vscode-remote?line=0'>1</a> ss = SparkSession.builder.appName('challenge').getOrCreate()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/flo/dssp/15-challenge/work.ipynb#ch0000004vscode-remote?line=1'>2</a> sc = ss.sparkContext
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/flo/dssp/15-challenge/work.ipynb#ch0000004vscode-remote?line=3'>4</a> dft = ss.read.csv("node_information.csv")
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/flo/dssp/15-challenge/work.ipynb#ch0000004vscode-remote?line=4'>5</a> df_nodes = dft.toDF("id", "year", "topics", "authors", "temp1", "text")
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/flo/dssp/15-challenge/work.ipynb#ch0000004vscode-remote?line=5'>6</a> df_nodes.createOrReplaceTempView("nodes")
#
# File /opt/spark/python/pyspark/sql/readwriter.py:410, in DataFrameReader.csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     <a href='file:///opt/spark/python/pyspark/sql/readwriter.py?line=407'>408</a>     path = [path]
#     <a href='file:///opt/spark/python/pyspark/sql/readwriter.py?line=408'>409</a> if type(path) == list:
# --> <a href='file:///opt/spark/python/pyspark/sql/readwriter.py?line=409'>410</a>     return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     <a href='file:///opt/spark/python/pyspark/sql/readwriter.py?line=410'>411</a> elif isinstance(path, RDD):
#     <a href='file:///opt/spark/python/pyspark/sql/readwriter.py?line=411'>412</a>     def func(iterator):
#
# File /opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1314'>1315</a> command = proto.CALL_COMMAND_NAME +\
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1315'>1316</a>     self.command_header +\
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1316'>1317</a>     args_command +\
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1317'>1318</a>     proto.END_COMMAND_PART
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1319'>1320</a> answer = self.gateway_client.send_command(command)
# -> <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1320'>1321</a> return_value = get_return_value(
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1321'>1322</a>     answer, self.gateway_client, self.target_id, self.name)
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1323'>1324</a> for temp_arg in temp_args:
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1324'>1325</a>     temp_arg._detach()
#
# File /opt/spark/python/pyspark/sql/utils.py:117, in capture_sql_exception.<locals>.deco(*a, **kw)
#     <a href='file:///opt/spark/python/pyspark/sql/utils.py?line=112'>113</a> converted = convert_exception(e.java_exception)
#     <a href='file:///opt/spark/python/pyspark/sql/utils.py?line=113'>114</a> if not isinstance(converted, UnknownException):
#     <a href='file:///opt/spark/python/pyspark/sql/utils.py?line=114'>115</a>     # Hide where the exception came from that shows a non-Pythonic
#     <a href='file:///opt/spark/python/pyspark/sql/utils.py?line=115'>116</a>     # JVM exception message.
# --> <a href='file:///opt/spark/python/pyspark/sql/utils.py?line=116'>117</a>     raise converted from None
#     <a href='file:///opt/spark/python/pyspark/sql/utils.py?line=117'>118</a> else:
#     <a href='file:///opt/spark/python/pyspark/sql/utils.py?line=118'>119</a>     raise
#
# AnalysisException: Path does not exist: file:/home/flo/dssp/15-challenge/node_information.csv

# %% [markdown]
# # Graphe des articles

# %%
df_nodes.head(1)
df_edges.head(1)
# Out:
# [Row(source='9510123', target='9502114', cites='1')]

# %%
from pyspark.sql.functions import lower, col

# transformation des dataframes pour qu'ils soient utilisables par GraphFrames
v=df_edges.rdd.flatMap(lambda x:[[x['source']],[x['target']]]).toDF(["id"]).distinct()
e=df_edges.select( col("source").alias("src"),col("target").alias("dst"), col('cites').alias('cites') )

# crétion du graphe des articles
articles_graph = graphframes.GraphFrame(v ,e)
in_degrees = articles_graph.inDegrees

# %%
def in_degrees_feature(edges, in_degrees):

    return edges.join(in_degrees, edges.dst == in_degrees.id).drop(in_degrees.id)

# %%
zou = in_degrees_feature(e, in_degrees=in_degrees)
zou.show()
# Out:
# +-------+-------+-----+--------+
# |    src|    dst|cites|inDegree|
# +-------+-------+-----+--------+
# |9510123|9502114|    1|      20|
# |9707075|9604178|    1|     132|
# |9312155|9506142|    0|       8|
# |9911255| 302165|    0|      12|
# |9701033| 209076|    0|      12|
# |9710020|9709228|    1|      21|
# |9901042|9510135|    1|     737|
# | 209146|9502077|    0|      70|
# |9705079|9702201|    1|      81|
# |   3016|9207067|    0|      46|
# |9402099| 105041|    0|      13|
# |9705061|9503216|    1|      10|
# | 109090|   9107|    0|      14|
# | 107016|9304156|    0|      17|
# |9812004|9212092|    0|      15|
# |9401058|9511114|    0|      12|
# |  12261| 202126|    0|      30|
# | 207246|9807137|    1|      85|
# |9501144|9311081|    1|      54|
# |9304048|9510008|    0|      28|
# +-------+-------+-----+--------+
# only showing top 20 rows

# %% [markdown]
# # Graphe d'auteurs

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.functions import lower, col
import numpy as np
from pyspark.ml.linalg import SparseVector, VectorUDT
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.sql.types import ArrayType

def explode_authors(row):
    my_input=row.asDict()

    my_output=[]
    #if my_input['author']==None or my_input['cited'] == None : my_output['author']='' #We want o avoid any null issues

    for author in my_input['author'].split(','):
        for cited in my_input['cited'].split(','):
            ret = {}
            ret['src'] = str(author).strip()
            ret['dst'] = str(cited).strip()
            newRow = Row(*ret.keys()) #a. the Row object specification (column names)
            newRow = newRow(*ret.values())#b. the corresponding column values

            my_output.append(newRow)
    return my_output

# %%
author_edges = ss.sql("select A.authors author, B.authors cited, edges.cites \
       from edges inner join nodes A on edges.target = A.id \
                   inner join nodes B on edges.source = B.id \
       where edges.cites = 1 and A.authors is not null and B.authors is not null")

author_edges.rdd.flatMap(explode_authors).collect()
# Out:
# [Row(src='Atish Dabholkar', dst='L.E.Ibanez'),
#  Row(src='Atish Dabholkar', dst='A.M.Uranga'),
#  Row(src='Jaemo Park', dst='L.E.Ibanez'),
#  Row(src='Jaemo Park', dst='A.M.Uranga'),
#  Row(src='Cumrun Vafa', dst='G. Michaud'),
#  Row(src='Cumrun Vafa', dst='R. C. Myers'),
#  Row(src='Swapna Mahapatra', dst='Sukanta Bose'),
#  Row(src='Swapna Mahapatra', dst='Sayan Kar'),
#  Row(src='Karmadeva Maharana', dst='Sukanta Bose'),
#  Row(src='Karmadeva Maharana', dst='Sayan Kar'),
#  Row(src='Lambodar P. Singh', dst='Sukanta Bose'),
#  Row(src='Lambodar P. Singh', dst='Sayan Kar'),
#  Row(src='H.J. Boonstra', dst='Hitoshi Nishino'),
#  Row(src='H.J. Boonstra', dst='Subhash Rajpoot'),
#  Row(src='K. Skenderis', dst='Hitoshi Nishino'),
#  Row(src='K. Skenderis', dst='Subhash Rajpoot'),
#  Row(src='P.K. Townsend', dst='Hitoshi Nishino'),
#  Row(src='P.K. Townsend', dst='Subhash Rajpoot'),
#  Row(src='D.I.Olive', dst='M.B. Halpern'),
#  Row(src='D.I.Olive', dst='E. Kiritsis'),
#  Row(src='D.I.Olive', dst='N. Obers'),
#  Row(src='D.I.Olive', dst='K. Clubok'),
#  Row(src='E.Rabinovici', dst='M.B. Halpern'),
#  Row(src='E.Rabinovici', dst='E. Kiritsis'),
#  Row(src='E.Rabinovici', dst='N. Obers'),
#  Row(src='E.Rabinovici', dst='K. Clubok'),
#  Row(src='A.Schwimmer', dst='M.B. Halpern'),
#  Row(src='A.Schwimmer', dst='E. Kiritsis'),
#  Row(src='A.Schwimmer', dst='N. Obers'),
#  Row(src='A.Schwimmer', dst='K. Clubok'),
#  Row(src='Juan M. Maldacena', dst='Andrew Strominger'),
#  Row(src='G.W. Delius', dst='S. Penati'),
#  Row(src='G.W. Delius', dst='D. Zanon'),
#  Row(src='M.T. Grisaru', dst='S. Penati'),
#  Row(src='M.T. Grisaru', dst='D. Zanon'),
#  Row(src='D. Zanon', dst='S. Penati'),
#  Row(src='D. Zanon', dst='D. Zanon'),
#  Row(src='J. Fuchs', dst='C. Schweigert'),
#  Row(src='J. Fuchs', dst='J. Fuchs'),
#  Row(src='J. Fuchs', dst='J. Walcher'),
#  Row(src='C. Schweigert', dst='C. Schweigert'),
#  Row(src='C. Schweigert', dst='J. Fuchs'),
#  Row(src='C. Schweigert', dst='J. Walcher'),
#  Row(src='J. Walcher', dst='C. Schweigert'),
#  Row(src='J. Walcher', dst='J. Fuchs'),
#  Row(src='J. Walcher', dst='J. Walcher'),
#  Row(src='A. Fring', dst='E. Corrigan'),
#  Row(src='R.Koberle', dst='E. Corrigan'),
#  Row(src='A.Galperin', dst='P. A. Grassi'),
#  Row(src='A.Galperin', dst='G. Policastro'),
#  Row(src='A.Galperin', dst='M. Porrati'),
#  Row(src='E.Sokatchev', dst='P. A. Grassi'),
#  Row(src='E.Sokatchev', dst='G. Policastro'),
#  Row(src='E.Sokatchev', dst='M. Porrati'),
#  Row(src='Michele Maggiore (INFN', dst='G. Veneziano'),
#  Row(src='Dept. of Phys.', dst='G. Veneziano'),
#  Row(src='Pisa)', dst='G. Veneziano'),
#  Row(src='Antonio Riotto', dst='G. Veneziano'),
#  Row(src='M. J. Duff', dst='Mans Henningson'),
#  Row(src='M. J. Duff', dst='Kostas Skenderis'),
#  Row(src='S. S. Gubser', dst='E. Sezgin'),
#  Row(src='S. S. Gubser', dst='P. Sundell'),
#  Row(src='I. R. Klebanov', dst='E. Sezgin'),
#  Row(src='I. R. Klebanov', dst='P. Sundell'),
#  Row(src='', dst='E. Sezgin'),
#  Row(src='', dst='P. Sundell'),
#  Row(src='A. M. Polyakov', dst='E. Sezgin'),
#  Row(src='A. M. Polyakov', dst='P. Sundell'),
#  Row(src='A.A. Tseytlin', dst='E. Kiritsis'),
#  Row(src='A.A. Tseytlin', dst='C. Kounnas'),
#  Row(src='A.A. Tseytlin', dst='D. Lust'),
#  Row(src='Donald Marolf', dst='C.P. Burgess'),
#  Row(src='Donald Marolf', dst='F. Quevedo'),
#  Row(src='Donald Marolf', dst='S.-J. Rey'),
#  Row(src='Donald Marolf', dst='G. Tasinato'),
#  Row(src='Donald Marolf', dst='I. Zavala'),
#  Row(src='Mark Trodden', dst='C.P. Burgess'),
#  Row(src='Mark Trodden', dst='F. Quevedo'),
#  Row(src='Mark Trodden', dst='S.-J. Rey'),
#  Row(src='Mark Trodden', dst='G. Tasinato'),
#  Row(src='Mark Trodden', dst='I. Zavala'),
#  Row(src='David J. Gross', dst='A. Belhaj'),
#  Row(src='David J. Gross', dst='J.J. Manjarin'),
#  Row(src='David J. Gross', dst='P. Resco'),
#  Row(src='Nikita A. Nekrasov', dst='A. Belhaj'),
#  Row(src='Nikita A. Nekrasov', dst='J.J. Manjarin'),
#  Row(src='Nikita A. Nekrasov', dst='P. Resco'),
#  Row(src='Yosuke Imamura', dst='Keshav Dasgupta'),
#  Row(src='Yosuke Imamura', dst='Govindan Rajesh'),
#  Row(src='Yosuke Imamura', dst='Daniel Robbins'),
#  Row(src='Yosuke Imamura', dst='Savdeep Sethi'),
#  Row(src='George Lavrelashvili', dst='Burkhard Kleihaus'),
#  Row(src='George Lavrelashvili', dst='Jutta Kunz'),
#  Row(src='George Lavrelashvili', dst='Abha Sood'),
#  Row(src='Dieter Maison', dst='Burkhard Kleihaus'),
#  Row(src='Dieter Maison', dst='Jutta Kunz'),
#  Row(src='Dieter Maison', dst='Abha Sood'),
#  Row(src='Edward Farhi', dst='E. Farhi'),
#  Row(src='Edward Farhi', dst='N. Graham'),
#  Row(src='Edward Farhi', dst='R.L. Jaffe'),
#  Row(src='Edward Farhi', dst=''),
#  Row(src='Edward Farhi', dst='H. Weigel'),
#  Row(src='Noah Graham', dst='E. Farhi'),
#  Row(src='Noah Graham', dst='N. Graham'),
#  Row(src='Noah Graham', dst='R.L. Jaffe'),
#  Row(src='Noah Graham', dst=''),
#  Row(src='Noah Graham', dst='H. Weigel'),
#  Row(src='Peter E. Haagensen', dst='E. Farhi'),
#  Row(src='Peter E. Haagensen', dst='N. Graham'),
#  Row(src='Peter E. Haagensen', dst='R.L. Jaffe'),
#  Row(src='Peter E. Haagensen', dst=''),
#  Row(src='Peter E. Haagensen', dst='H. Weigel'),
#  Row(src='Robert L. Jaffe', dst='E. Farhi'),
#  Row(src='Robert L. Jaffe', dst='N. Graham'),
#  Row(src='Robert L. Jaffe', dst='R.L. Jaffe'),
#  Row(src='Robert L. Jaffe', dst=''),
#  Row(src='Robert L. Jaffe', dst='H. Weigel'),
#  Row(src='Gottfried Curio', dst='Umut Gursoy'),
#  Row(src='Gottfried Curio', dst='Carlos Nunez'),
#  Row(src='Gottfried Curio', dst='Martin Schvellinger'),
#  Row(src='Boris Kors', dst='Umut Gursoy'),
#  Row(src='Boris Kors', dst='Carlos Nunez'),
#  Row(src='Boris Kors', dst='Martin Schvellinger'),
#  Row(src='Dieter Lust', dst='Umut Gursoy'),
#  Row(src='Dieter Lust', dst='Carlos Nunez'),
#  Row(src='Dieter Lust', dst='Martin Schvellinger'),
#  Row(src='A. Strominger', dst='Mirjam Cvetic'),
#  Row(src='A. Strominger', dst='Finn Larsen'),
#  Row(src='C. Vafa', dst='Mirjam Cvetic'),
#  Row(src='C. Vafa', dst='Finn Larsen'),
#  Row(src='Gilad Lifschytz (Br', dst='Daniel Kabat (IAS)'),
#  Row(src='Gilad Lifschytz (Br', dst='Gilad Lifschytz (Princeton University)'),
#  Row(src='eis University)', dst='Daniel Kabat (IAS)'),
#  Row(src='eis University)', dst='Gilad Lifschytz (Princeton University)'),
#  Row(src='G. Barnich', dst='Joaquim Gomis'),
#  Row(src='G. Barnich', dst='Jordi Paris'),
#  Row(src='G. Barnich', dst='Stuart Samuel'),
#  Row(src='F. Br', dst='Joaquim Gomis'),
#  Row(src='F. Br', dst='Jordi Paris'),
#  Row(src='F. Br', dst='Stuart Samuel'),
#  Row(src='t', dst='Joaquim Gomis'),
#  Row(src='t', dst='Jordi Paris'),
#  Row(src='t', dst='Stuart Samuel'),
#  Row(src='M. Henneaux', dst='Joaquim Gomis'),
#  Row(src='M. Henneaux', dst='Jordi Paris'),
#  Row(src='M. Henneaux', dst='Stuart Samuel'),
#  Row(src='Avinash Dhar', dst='Justin R. David'),
#  Row(src='Avinash Dhar', dst='Gautam M'),
#  Row(src='Avinash Dhar', dst='al'),
#  Row(src='Avinash Dhar', dst='Spenta R. Wadia'),
#  Row(src='Gautam M', dst='Justin R. David'),
#  Row(src='Gautam M', dst='Gautam M'),
#  Row(src='Gautam M', dst='al'),
#  Row(src='Gautam M', dst='Spenta R. Wadia'),
#  Row(src='al', dst='Justin R. David'),
#  Row(src='al', dst='Gautam M'),
#  Row(src='al', dst='al'),
#  Row(src='al', dst='Spenta R. Wadia'),
#  Row(src='Spenta R. Wadia', dst='Justin R. David'),
#  Row(src='Spenta R. Wadia', dst='Gautam M'),
#  Row(src='Spenta R. Wadia', dst='al'),
#  Row(src='Spenta R. Wadia', dst='Spenta R. Wadia'),
#  Row(src='H. Grosse', dst='A. P. Balach'),
#  Row(src='H. Grosse', dst='ran'),
#  Row(src='H. Grosse', dst='T. R. Govindarajan'),
#  Row(src='H. Grosse', dst='B. Ydri'),
#  Row(src='C. Klimcik', dst='A. P. Balach'),
#  Row(src='C. Klimcik', dst='ran'),
#  Row(src='C. Klimcik', dst='T. R. Govindarajan'),
#  Row(src='C. Klimcik', dst='B. Ydri'),
#  Row(src='P. Presnajder', dst='A. P. Balach'),
#  Row(src='P. Presnajder', dst='ran'),
#  Row(src='P. Presnajder', dst='T. R. Govindarajan'),
#  Row(src='P. Presnajder', dst='B. Ydri'),
#  Row(src='Edward Witten', dst='Freddy Cachazo'),
#  Row(src='Edward Witten', dst='Michael R. Douglas'),
#  Row(src='Edward Witten', dst='Nathan Seiberg'),
#  Row(src='Edward Witten', dst='Edward Witten'),
#  Row(src='"G. Felder', dst="JM Figueroa-O'Farrill"),
#  Row(src='"G. Felder', dst='S Stanciu'),
#  Row(src='J. Fr""ohlich', dst="JM Figueroa-O'Farrill"),
#  Row(src='J. Fr""ohlich', dst='S Stanciu'),
#  Row(src='E. I. Buchbinder', dst='A.T. Banin'),
#  Row(src='E. I. Buchbinder', dst='I.L. Buchbinder'),
#  Row(src='E. I. Buchbinder', dst='N.G. Pletnev'),
#  Row(src='I. L. Buchbinder', dst='A.T. Banin'),
#  Row(src='I. L. Buchbinder', dst='I.L. Buchbinder'),
#  Row(src='I. L. Buchbinder', dst='N.G. Pletnev'),
#  Row(src='S. M. Kuzenko', dst='A.T. Banin'),
#  Row(src='S. M. Kuzenko', dst='I.L. Buchbinder'),
#  Row(src='S. M. Kuzenko', dst='N.G. Pletnev'),
#  Row(src='Mans Henningson', dst='Enrique Alvarez'),
#  Row(src='Mans Henningson', dst='Cesar Gomez'),
#  Row(src='Kostas Skenderis', dst='Enrique Alvarez'),
#  Row(src='Kostas Skenderis', dst='Cesar Gomez'),
#  Row(src='Carlos Barcelo (Washington University in Saint Louis)', dst='Csaba Csaki'),
#  Row(src='Carlos Barcelo (Washington University in Saint Louis)', dst='Michael L. Graesser'),
#  Row(src='Carlos Barcelo (Washington University in Saint Louis)', dst='Graham D. Kribs'),
#  Row(src='Matt Visser', dst='Csaba Csaki'),
#  Row(src='Matt Visser', dst='Michael L. Graesser'),
#  Row(src='Matt Visser', dst='Graham D. Kribs'),
#  Row(src='Hsien-Chung Kao', dst='Mina Aganagic'),
#  Row(src='Hsien-Chung Kao', dst='Kentaro Hori'),
#  Row(src='Hsien-Chung Kao', dst='Andreas Karch'),
#  Row(src='Hsien-Chung Kao', dst='David Tong'),
#  Row(src='Kimyeong Lee', dst='Mina Aganagic'),
#  Row(src='Kimyeong Lee', dst='Kentaro Hori'),
#  Row(src='Kimyeong Lee', dst='Andreas Karch'),
#  Row(src='Kimyeong Lee', dst='David Tong'),
#  Row(src='L. Susskind', dst='Miguel E. Ortiz'),
#  Row(src='L. Thorlacius', dst='Miguel E. Ortiz'),
#  Row(src='', dst='Miguel E. Ortiz'),
#  Row(src='J. Uglum', dst='Miguel E. Ortiz'),
#  Row(src='N. Chair', dst='H. Arfaei'),
#  Row(src='N. Chair', dst=''),
#  Row(src='N. Chair', dst='M. H. Yavartanoo'),
#  Row(src='M.M. Sheikh-Jabbari', dst='H. Arfaei'),
#  Row(src='M.M. Sheikh-Jabbari', dst=''),
#  Row(src='M.M. Sheikh-Jabbari', dst='M. H. Yavartanoo'),
#  Row(src='O. Aharony', dst='Csaba Csaki'),
#  Row(src='O. Aharony', dst='Joshua Erlich'),
#  Row(src='O. Aharony', dst='Timothy J. Hollowood'),
#  Row(src='O. Aharony', dst='John Terning'),
#  Row(src='S.S. Gubser', dst='Csaba Csaki'),
#  Row(src='S.S. Gubser', dst='Joshua Erlich'),
#  Row(src='S.S. Gubser', dst='Timothy J. Hollowood'),
#  Row(src='S.S. Gubser', dst='John Terning'),
#  Row(src='J. Maldacena', dst='Csaba Csaki'),
#  Row(src='J. Maldacena', dst='Joshua Erlich'),
#  Row(src='J. Maldacena', dst='Timothy J. Hollowood'),
#  Row(src='J. Maldacena', dst='John Terning'),
#  Row(src='H. Ooguri', dst='Csaba Csaki'),
#  Row(src='H. Ooguri', dst='Joshua Erlich'),
#  Row(src='H. Ooguri', dst='Timothy J. Hollowood'),
#  Row(src='H. Ooguri', dst='John Terning'),
#  Row(src='', dst='Csaba Csaki'),
#  Row(src='', dst='Joshua Erlich'),
#  Row(src='', dst='Timothy J. Hollowood'),
#  Row(src='', dst='John Terning'),
#  Row(src='Y. Oz', dst='Csaba Csaki'),
#  Row(src='Y. Oz', dst='Joshua Erlich'),
#  Row(src='Y. Oz', dst='Timothy J. Hollowood'),
#  Row(src='Y. Oz', dst='John Terning'),
#  Row(src='Suresh Govindarajan', dst='Micha Berkooz'),
#  Row(src='Suresh Govindarajan', dst='Moshe Rozali'),
#  Row(src='O. Bergman', dst='M. R. Gaberdiel'),
#  Row(src='O. Bergman', dst='B. Stefanski Jr'),
#  Row(src='M.R. Gaberdiel', dst='M. R. Gaberdiel'),
#  Row(src='M.R. Gaberdiel', dst='B. Stefanski Jr'),
#  Row(src='Jin-Ho Cho', dst='Dongsu Bak'),
#  Row(src='Jin-Ho Cho', dst='Kimyeong Lee'),
#  Row(src='Phillial Oh', dst='Dongsu Bak'),
#  Row(src='Phillial Oh', dst='Kimyeong Lee'),
#  Row(src='Kevin Goldstein', dst='Nemanja Kaloper'),
#  Row(src='Kevin Goldstein', dst='Matthew Kleban'),
#  Row(src='Kevin Goldstein', dst='Albion Lawrence'),
#  Row(src='Kevin Goldstein', dst='Stephen Shenker'),
#  Row(src='Kevin Goldstein', dst=''),
#  Row(src='David A. Lowe', dst='Nemanja Kaloper'),
#  Row(src='David A. Lowe', dst='Matthew Kleban'),
#  Row(src='David A. Lowe', dst='Albion Lawrence'),
#  Row(src='David A. Lowe', dst='Stephen Shenker'),
#  Row(src='David A. Lowe', dst=''),
#  Row(src='Per Kraus', dst='Horace Stoica'),
#  Row(src='J.C. Le Guillou', dst='Jose D. Edelstein'),
#  Row(src='J.C. Le Guillou', dst='Carlos Nunez'),
#  Row(src="C. N\\'u\\~nez", dst='Jose D. Edelstein'),
#  Row(src="C. N\\'u\\~nez", dst='Carlos Nunez'),
#  Row(src='F.A. Schaposnik', dst='Jose D. Edelstein'),
#  Row(src='F.A. Schaposnik', dst='Carlos Nunez'),
#  Row(src='R.R. Metsaev', dst='Michael R. Douglas'),
#  Row(src='R.R. Metsaev', dst='S. R'),
#  Row(src='R.R. Metsaev', dst='jbar-Daemi'),
#  Row(src='A.A. Tseytlin', dst='Michael R. Douglas'),
#  Row(src='A.A. Tseytlin', dst='S. R'),
#  Row(src='A.A. Tseytlin', dst='jbar-Daemi'),
#  Row(src='P. A. Grassi', dst='P.A. Grassi (YITP'),
#  Row(src='P. A. Grassi', dst='Stony Brook)'),
#  Row(src='P. A. Grassi', dst='G. Policastro (Scuola Normale Pisa'),
#  Row(src='G. Policastro', dst='P.A. Grassi (YITP'),
#  Row(src='G. Policastro', dst='Stony Brook)'),
#  Row(src='G. Policastro', dst='G. Policastro (Scuola Normale Pisa'),
#  Row(src='M. Porrati', dst='P.A. Grassi (YITP'),
#  Row(src='M. Porrati', dst='Stony Brook)'),
#  Row(src='M. Porrati', dst='G. Policastro (Scuola Normale Pisa'),
#  Row(src='P. van Nieuwenhuizen', dst='P.A. Grassi (YITP'),
#  Row(src='P. van Nieuwenhuizen', dst='Stony Brook)'),
#  Row(src='P. van Nieuwenhuizen', dst='G. Policastro (Scuola Normale Pisa'),
#  Row(src='A. Smilga', dst='D. Toublan'),
#  Row(src='A. Smilga', dst='J.J.M. Verbaarschot'),
#  Row(src='J. Verbaarschot', dst='D. Toublan'),
#  Row(src='J. Verbaarschot', dst='J.J.M. Verbaarschot'),
#  Row(src='Scott Ness', dst="Shin'ichi Nojiri"),
#  Row(src='Scott Ness', dst='Sergei D. Odintsov'),
#  Row(src='George Siopsis', dst="Shin'ichi Nojiri"),
#  Row(src='George Siopsis', dst='Sergei D. Odintsov'),
#  Row(src='E. Alvarez', dst='E. Alvarez'),
#  Row(src='E. Alvarez', dst='J. Borlaf'),
#  Row(src='E. Alvarez', dst="J.H. Le\\'on"),
#  Row(src='J. Borlaf', dst='E. Alvarez'),
#  Row(src='J. Borlaf', dst='J. Borlaf'),
#  Row(src='J. Borlaf', dst="J.H. Le\\'on"),
#  Row(src="J.H. Le\\'on (UAM", dst='E. Alvarez'),
#  Row(src="J.H. Le\\'on (UAM", dst='J. Borlaf'),
#  Row(src="J.H. Le\\'on (UAM", dst="J.H. Le\\'on"),
#  Row(src='Madrid)', dst='E. Alvarez'),
#  Row(src='Madrid)', dst='J. Borlaf'),
#  Row(src='Madrid)', dst="J.H. Le\\'on"),
#  Row(src='Jan de Boer', dst='Oleg Lunin'),
#  Row(src='Jan de Boer', dst='Juan Maldacena'),
#  Row(src='Jan de Boer', dst='Liat Maoz'),
#  Row(src='C. I. Lazaroiu', dst='C. I. Lazaroiu'),
#  Row(src='C. I. Lazaroiu', dst='R. Roiban'),
#  Row(src='Akikazu Hashimoto', dst='I. Antoniadis'),
#  Row(src='Akikazu Hashimoto', dst='K. Benakli'),
#  Row(src='Akikazu Hashimoto', dst='A.Laugier'),
#  Row(src='Igor R. Klebanov', dst='I. Antoniadis'),
#  Row(src='Igor R. Klebanov', dst='K. Benakli'),
#  Row(src='Igor R. Klebanov', dst='A.Laugier'),
#  Row(src='Shiraz Minwalla', dst='I.V. Volovich'),
#  Row(src='Washington Taylor (MIT)', dst='Arvind Rajaraman'),
#  Row(src='Ali H. Chamseddine (CAMS', dst='H. Garcia-Compean'),
#  Row(src='Ali H. Chamseddine (CAMS', dst='O. Obregon'),
#  Row(src='Ali H. Chamseddine (CAMS', dst='C. Ramirez'),
#  Row(src='Ali H. Chamseddine (CAMS', dst='M. Sabido'),
#  Row(src='AUB)', dst='H. Garcia-Compean'),
#  Row(src='AUB)', dst='O. Obregon'),
#  Row(src='AUB)', dst='C. Ramirez'),
#  Row(src='AUB)', dst='M. Sabido'),
#  Row(src='R. Br', dst='A. Notari (Scuola Normale Superiore'),
#  Row(src='R. Br', dst='Pisa)'),
#  Row(src='R. Br', dst='A. Riotto (INFN'),
#  Row(src='R. Br', dst='Padova)'),
#  Row(src='enberger (Brown U.)', dst='A. Notari (Scuola Normale Superiore'),
#  Row(src='enberger (Brown U.)', dst='Pisa)'),
#  Row(src='enberger (Brown U.)', dst='A. Riotto (INFN'),
#  Row(src='enberger (Brown U.)', dst='Padova)'),
#  Row(src='F. Finelli (Purdue U.)', dst='A. Notari (Scuola Normale Superiore'),
#  Row(src='F. Finelli (Purdue U.)', dst='Pisa)'),
#  Row(src='F. Finelli (Purdue U.)', dst='A. Riotto (INFN'),
#  Row(src='F. Finelli (Purdue U.)', dst='Padova)'),
#  Row(src='Andrea Refolli', dst='Paul Koerber'),
#  Row(src='Andrea Refolli', dst='Alex'),
#  Row(src='Andrea Refolli', dst='er Sevrin'),
#  Row(src='Alberto Santambrogio', dst='Paul Koerber'),
#  Row(src='Alberto Santambrogio', dst='Alex'),
#  Row(src='Alberto Santambrogio', dst='er Sevrin'),
#  Row(src="Niccolo' Terzi", dst='Paul Koerber'),
#  Row(src="Niccolo' Terzi", dst='Alex'),
#  Row(src="Niccolo' Terzi", dst='er Sevrin'),
#  Row(src='Daniela Zanon', dst='Paul Koerber'),
#  Row(src='Daniela Zanon', dst='Alex'),
#  Row(src='Daniela Zanon', dst='er Sevrin'),
#  Row(src='J. Polchinski', dst='Alex'),
#  Row(src='J. Polchinski', dst='er Maloney'),
#  Row(src='J. Polchinski', dst='Andrew Strominger'),
#  Row(src='J. Polchinski', dst='Xi Yin'),
#  Row(src='L. Thorlacius', dst='Alex'),
#  Row(src='L. Thorlacius', dst='er Maloney'),
#  Row(src='L. Thorlacius', dst='Andrew Strominger'),
#  Row(src='L. Thorlacius', dst='Xi Yin'),
#  Row(src='Juan M. Maldacena', dst='James Babington'),
#  Row(src='Juan M. Maldacena', dst='David E. Crooks'),
#  Row(src='Juan M. Maldacena', dst='Nick Evans'),
#  Row(src='Tadashi Takayanagi', dst='J. Kluson'),
#  Row(src='A.Gorsky', dst='A.Gorsky'),
#  Row(src='A.Gorsky', dst='A.Mironov'),
#  Row(src='A.Mironov', dst='A.Gorsky'),
#  Row(src='A.Mironov', dst='A.Mironov'),
#  Row(src='V.V. Nesterenko', dst='G.Arreaga'),
#  Row(src='V.V. Nesterenko', dst='R. Capovilla'),
#  Row(src='V.V. Nesterenko', dst='J. Guven'),
#  Row(src='A. Feoli', dst='G.Arreaga'),
#  Row(src='A. Feoli', dst='R. Capovilla'),
#  Row(src='A. Feoli', dst='J. Guven'),
#  Row(src='G. Scarpetta', dst='G.Arreaga'),
#  Row(src='G. Scarpetta', dst='R. Capovilla'),
#  Row(src='G. Scarpetta', dst='J. Guven'),
#  Row(src='M. Gasperini', dst='M. Sami'),
#  Row(src='M. Gasperini', dst='Pravabati Chingangbam'),
#  Row(src='M. Gasperini', dst='Tabish Qureshi'),
#  Row(src='G. Veneziano', dst='M. Sami'),
#  Row(src='G. Veneziano', dst='Pravabati Chingangbam'),
#  Row(src='G. Veneziano', dst='Tabish Qureshi'),
#  Row(src='C.M. Hull (QMW)', dst='A.J.M. Medved (University of Alberta)'),
#  Row(src='L. Susskind', dst='Konstantin G. Zloshchastiev'),
#  Row(src='H. Hata', dst='T. Nakatsu'),
#  Row(src='B. Zwiebach', dst='T. Nakatsu'),
#  Row(src='N. Dorey', dst='Donald Marolf'),
#  Row(src='N. Dorey', dst='Simon F. Ross'),
#  Row(src='V. V. Khoze', dst='Donald Marolf'),
#  Row(src='V. V. Khoze', dst='Simon F. Ross'),
#  Row(src='M. P. Mattis', dst='Donald Marolf'),
#  Row(src='M. P. Mattis', dst='Simon F. Ross'),
#  Row(src='D. Tong', dst='Donald Marolf'),
#  Row(src='D. Tong', dst='Simon F. Ross'),
#  Row(src='S. V', dst='Donald Marolf'),
#  Row(src='S. V', dst='Simon F. Ross'),
#  Row(src='oren', dst='Donald Marolf'),
#  Row(src='oren', dst='Simon F. Ross'),
#  Row(src='K.Becker', dst='Jerome P. Gauntlett'),
#  Row(src='K.Becker', dst='Gary W. Gibbons'),
#  Row(src='K.Becker', dst='Paul K. Townsend'),
#  Row(src='M.Becker', dst='Jerome P. Gauntlett'),
#  Row(src='M.Becker', dst='Gary W. Gibbons'),
#  Row(src='M.Becker', dst='Paul K. Townsend'),
#  Row(src='D.R.Morrison', dst='Jerome P. Gauntlett'),
#  Row(src='D.R.Morrison', dst='Gary W. Gibbons'),
#  Row(src='D.R.Morrison', dst='Paul K. Townsend'),
#  Row(src='H.Ooguri', dst='Jerome P. Gauntlett'),
#  Row(src='H.Ooguri', dst='Gary W. Gibbons'),
#  Row(src='H.Ooguri', dst='Paul K. Townsend'),
#  Row(src='Y.Oz', dst='Jerome P. Gauntlett'),
#  Row(src='Y.Oz', dst='Gary W. Gibbons'),
#  Row(src='Y.Oz', dst='Paul K. Townsend'),
#  Row(src='Z.Yin', dst='Jerome P. Gauntlett'),
#  Row(src='Z.Yin', dst='Gary W. Gibbons'),
#  Row(src='Z.Yin', dst='Paul K. Townsend'),
#  Row(src='Bjorn Andreas', dst='Alon E. Faraggi'),
#  Row(src='Gottfried Curio', dst='Alon E. Faraggi'),
#  Row(src='Albrecht Klemm', dst='Alon E. Faraggi'),
#  Row(src='Joshua Feinberg', dst='Joshua Feinberg'),
#  Row(src='Volker Schomerus', dst='Lorenzo Cornalba'),
#  Row(src='Volker Schomerus', dst='Miguel S. Costa'),
#  Row(src='Volker Schomerus', dst='Ricardo Schiappa'),
#  Row(src='Axel Krause (Humboldt U.', dst='Ralph Blumenhagen'),
#  Row(src='Axel Krause (Humboldt U.', dst='Anamaria Font'),
#  Row(src='Berlin)', dst='Ralph Blumenhagen'),
#  Row(src='Berlin)', dst='Anamaria Font'),
#  Row(src='U. Ellwanger', dst='U. Ellwanger'),
#  Row(src='H. Grosse', dst='M. Chaichian'),
#  Row(src='H. Grosse', dst='A. Demichev'),
#  Row(src='H. Grosse', dst='P. Presnajder'),
#  Row(src='C. Klimcik', dst='M. Chaichian'),
#  Row(src='C. Klimcik', dst='A. Demichev'),
#  Row(src='C. Klimcik', dst='P. Presnajder'),
#  Row(src='P. Presnajder', dst='M. Chaichian'),
#  Row(src='P. Presnajder', dst='A. Demichev'),
#  Row(src='P. Presnajder', dst='P. Presnajder'),
#  Row(src='Timothy J. Hollowood', dst='Timothy J. Hollowood (University of Wales Swansea)'),
#  Row(src='Daniel Kabat', dst='Bernard de Wit'),
#  Row(src='Daniel Kabat', dst='Kasper Peeters'),
#  Row(src='Daniel Kabat', dst='Jan Plefka'),
#  Row(src='Philippe Pouliot', dst='Bernard de Wit'),
#  Row(src='Philippe Pouliot', dst='Kasper Peeters'),
#  Row(src='Philippe Pouliot', dst='Jan Plefka'),
#  Row(src='I. Chepelev', dst='A.T. Banin'),
#  Row(src='I. Chepelev', dst='I.L. Buchbinder'),
#  Row(src='I. Chepelev', dst='N.G. Pletnev'),
#  Row(src='A.A. Tseytlin', dst='A.T. Banin'),
#  Row(src='A.A. Tseytlin', dst='I.L. Buchbinder'),
#  Row(src='A.A. Tseytlin', dst='N.G. Pletnev'),
#  Row(src='Jean-Loup Gervais', dst='A. V. Razumov'),
#  Row(src='Jean-Loup Gervais', dst='M. V. Saveliev'),
#  Row(src='Mikhail V. Saveliev', dst='A. V. Razumov'),
#  Row(src='Mikhail V. Saveliev', dst='M. V. Saveliev'),
#  Row(src='J. Fuchs', dst='W. Lerche'),
#  Row(src='J. Fuchs', dst='J. Walcher'),
#  Row(src='C. Schweigert', dst='W. Lerche'),
#  Row(src='C. Schweigert', dst='J. Walcher'),
#  Row(src='Pei-Ming Ho', dst='I. Chepelev'),
#  Row(src='Pei-Ming Ho', dst='A.A. Tseytlin'),
#  Row(src='Yong-Shi Wu (Univ. of Utah)', dst='I. Chepelev'),
#  Row(src='Yong-Shi Wu (Univ. of Utah)', dst='A.A. Tseytlin'),
#  Row(src='D. Bailin', dst='L. F. Alday'),
#  Row(src='D. Bailin', dst='G. Aldazabal'),
#  Row(src='G. V. Kraniotis', dst='L. F. Alday'),
#  Row(src='G. V. Kraniotis', dst='G. Aldazabal'),
#  Row(src='A. Love', dst='L. F. Alday'),
#  Row(src='A. Love', dst='G. Aldazabal'),
#  Row(src='Jin-Ho Cho', dst='Dongsu Bak'),
#  Row(src='Jin-Ho Cho', dst='Nobuyoshi Ohta'),
#  Row(src='Jin-Ho Cho', dst='Mohammad M. Sheikh-Jabbari'),
#  Row(src='Phillial Oh', dst='Dongsu Bak'),
#  Row(src='Phillial Oh', dst='Nobuyoshi Ohta'),
#  Row(src='Phillial Oh', dst='Mohammad M. Sheikh-Jabbari'),
#  Row(src='Frank Ferrari (Princeton University)', dst='Frank Ferrari (Universite de Neuchatel'),
#  Row(src='Frank Ferrari (Princeton University)', dst='Princeton University)'),
#  Row(src='S. Naculich', dst='Iosif Bena'),
#  Row(src='S. Naculich', dst='Hitoshi Murayama'),
#  Row(src='S. Naculich', dst='Radu Roiban'),
#  Row(src='S. Naculich', dst='Radu Tatar'),
#  Row(src='H. Schnitzer', dst='Iosif Bena'),
#  Row(src='H. Schnitzer', dst='Hitoshi Murayama'),
#  Row(src='H. Schnitzer', dst='Radu Roiban'),
#  Row(src='H. Schnitzer', dst='Radu Tatar'),
#  Row(src='N. Wyllard', dst='Iosif Bena'),
#  Row(src='N. Wyllard', dst='Hitoshi Murayama'),
#  Row(src='N. Wyllard', dst='Radu Roiban'),
#  Row(src='N. Wyllard', dst='Radu Tatar'),
#  Row(src='J. Russo', dst='Avinash Dhar'),
#  Row(src='J. Russo', dst='Gautam M'),
#  Row(src='J. Russo', dst='al'),
#  Row(src='J. Russo', dst='Spenta R. Wadia'),
#  Row(src='Thomas C. Kraan', dst='Thomas C. Kraan'),
#  Row(src='Pierre van Baal', dst='Thomas C. Kraan'),
#  Row(src='M.R. Douglas', dst='Michael Bershadsky'),
#  Row(src='M.R. Douglas', dst='Vladimir Sadov'),
#  Row(src='S. Katz', dst='Michael Bershadsky'),
#  Row(src='S. Katz', dst='Vladimir Sadov'),
#  Row(src='C. Vafa', dst='Michael Bershadsky'),
#  Row(src='C. Vafa', dst='Vladimir Sadov'),
#  Row(src='Piljin Yi', dst='J.F. Wheater'),
#  Row(src='Piljin Yi', dst='G. Vernizzi'),
#  Row(src='Ori J. Ganor', dst='Julie D. Blum'),
#  Row(src='Ori J. Ganor', dst='Kenneth Intriligator'),
#  Row(src='Amihay Hanany', dst='Julie D. Blum'),
#  Row(src='Amihay Hanany', dst='Kenneth Intriligator'),
#  Row(src='Cumrun Vafa', dst='P. Berglund'),
#  Row(src='Cumrun Vafa', dst='P. Mayr'),
#  Row(src='Tom Banks', dst='S. F. Hewson'),
#  Row(src='Tom Banks', dst='M. J. Perry'),
#  Row(src='Michael R. Douglas', dst='S. F. Hewson'),
#  Row(src='Michael R. Douglas', dst='M. J. Perry'),
#  Row(src='Nathan Seiberg', dst='S. F. Hewson'),
#  Row(src='Nathan Seiberg', dst='M. J. Perry'),
#  Row(src='Dae Sung Hwang', dst='Amitabha Lahiri (Bose Ctr.'),
#  Row(src='Dae Sung Hwang', dst='Kolkata)'),
#  Row(src='Chang-Yeong Lee', dst='Amitabha Lahiri (Bose Ctr.'),
#  Row(src='Chang-Yeong Lee', dst='Kolkata)'),
#  Row(src='Ashoke Sen', dst='K. Intriligator'),
#  Row(src='Ashoke Sen', dst='N. Seiberg'),
#  Row(src='H. Dorn', dst='Klaus Behrndt'),
#  Row(src='H. Dorn', dst='Ilka Brunner'),
#  Row(src='H. Dorn', dst='Ingo Gaida'),
#  Row(src='H.-J. Otto', dst='Klaus Behrndt'),
#  Row(src='H.-J. Otto', dst='Ilka Brunner'),
#  Row(src='H.-J. Otto', dst='Ingo Gaida'),
#  Row(src='Csaba Csaki', dst="Shin'ichi Nojiri"),
#  Row(src='Csaba Csaki', dst='Sergei D. Odintsov'),
#  Row(src='Joshua Erlich', dst="Shin'ichi Nojiri"),
#  Row(src='Joshua Erlich', dst='Sergei D. Odintsov'),
#  Row(src='Christophe Grojean', dst="Shin'ichi Nojiri"),
#  Row(src='Christophe Grojean', dst='Sergei D. Odintsov'),
#  Row(src='Timothy Hollowood', dst="Shin'ichi Nojiri"),
#  Row(src='Timothy Hollowood', dst='Sergei D. Odintsov'),
#  Row(src='Marc Henneaux', dst='Vijay Balasubramanian'),
#  Row(src='Marc Henneaux', dst='Jan de Boer'),
#  Row(src='Marc Henneaux', dst='Esko Keski-Vakkuri'),
#  Row(src='Marc Henneaux', dst='Simon F.'),
#  Row(src='Liat Maoz', dst='Vijay Balasubramanian'),
#  Row(src='Liat Maoz', dst='Jan de Boer'),
#  Row(src='Liat Maoz', dst='Esko Keski-Vakkuri'),
#  Row(src='Liat Maoz', dst='Simon F.'),
#  Row(src='Adam Schwimmer', dst='Vijay Balasubramanian'),
#  Row(src='Adam Schwimmer', dst='Jan de Boer'),
#  Row(src='Adam Schwimmer', dst='Esko Keski-Vakkuri'),
#  Row(src='Adam Schwimmer', dst='Simon F.'),
#  Row(src='S. Elitzur', dst='Takashi Yokono'),
#  Row(src='A. Giveon', dst='Takashi Yokono'),
#  Row(src='D. Kutasov', dst='Takashi Yokono'),
#  Row(src='E. Rabinovici', dst='Takashi Yokono'),
#  Row(src='A. Schwimmer', dst='Takashi Yokono'),
#  Row(src='Cumrun Vafa', dst='Amihay Hanany'),
#  Row(src='Cumrun Vafa', dst='Amer Iqbal'),
#  Row(src='Barton Zwiebach', dst='Amihay Hanany'),
#  Row(src='Barton Zwiebach', dst='Amer Iqbal'),
#  Row(src='Giampiero Esposito', dst='Giampiero Esposito'),
#  Row(src='Giampiero Esposito', dst='Alex'),
#  Row(src='Giampiero Esposito', dst='er Yu. Kamenshchik'),
#  Row(src='Giampiero Esposito', dst='Klaus Kirsten'),
#  Row(src='Alex', dst='Giampiero Esposito'),
#  Row(src='Alex', dst='Alex'),
#  Row(src='Alex', dst='er Yu. Kamenshchik'),
#  Row(src='Alex', dst='Klaus Kirsten'),
#  Row(src='er Yu. Kamenshchik', dst='Giampiero Esposito'),
#  Row(src='er Yu. Kamenshchik', dst='Alex'),
#  Row(src='er Yu. Kamenshchik', dst='er Yu. Kamenshchik'),
#  Row(src='er Yu. Kamenshchik', dst='Klaus Kirsten'),
#  Row(src='Klaus Kirsten', dst='Giampiero Esposito'),
#  Row(src='Klaus Kirsten', dst='Alex'),
#  Row(src='Klaus Kirsten', dst='er Yu. Kamenshchik'),
#  Row(src='Klaus Kirsten', dst='Klaus Kirsten'),
#  Row(src='Ofer Aharony', dst='Barak Kol'),
#  Row(src='Yaron Oz', dst='Barak Kol'),
#  Row(src='Zheng Yin', dst='Barak Kol'),
#  Row(src='P. Sutton', dst='T.S.Evans'),
#  Row(src='Min-xin Huang', dst='Changhyun Ahn'),
#  Row(src='A. Giveon', dst='Adi Armoni'),
#  Row(src='A. Giveon', dst='Barak Kol'),
#  Row(src='D. Kutasov', dst='Adi Armoni'),
#  Row(src='D. Kutasov', dst='Barak Kol'),
#  Row(src='"A. H. Chamseddine', dst='Mohsen Alishahiha'),
#  Row(src='G. Felder', dst='Mohsen Alishahiha'),
#  Row(src='', dst='Mohsen Alishahiha'),
#  Row(src='J. Fr""ohlich"', dst='Mohsen Alishahiha'),
#  Row(src='Paolo Pasti', dst='Alexey Maznytsia'),
#  Row(src='Paolo Pasti', dst='Christian R. Preitschopf'),
#  Row(src='Paolo Pasti', dst='Dmitri Sorokin'),
#  Row(src='Dmitrij Sorokin', dst='Alexey Maznytsia'),
#  Row(src='Dmitrij Sorokin', dst='Christian R. Preitschopf'),
#  Row(src='Dmitrij Sorokin', dst='Dmitri Sorokin'),
#  Row(src='Mario Tonin', dst='Alexey Maznytsia'),
#  Row(src='Mario Tonin', dst='Christian R. Preitschopf'),
#  Row(src='Mario Tonin', dst='Dmitri Sorokin'),
#  Row(src='David R. Morrison', dst='Evgeny Buchbinder'),
#  Row(src='David R. Morrison', dst='Ron Donagi'),
#  Row(src='David R. Morrison', dst='Burt A. Ovrut'),
#  Row(src='Cumrun Vafa', dst='Evgeny Buchbinder'),
#  Row(src='Cumrun Vafa', dst='Ron Donagi'),
#  Row(src='Cumrun Vafa', dst='Burt A. Ovrut'),
#  Row(src='N. Kawamoto', dst='Noboru Kawamoto'),
#  Row(src='K. Suehiro', dst='Noboru Kawamoto'),
#  Row(src='T. Tsukioka', dst='Noboru Kawamoto'),
#  Row(src='H. Umetsu', dst='Noboru Kawamoto'),
#  Row(src='Shinpei Kobayashi', dst="Shin'ichi Nojiri"),
#  Row(src='Shinpei Kobayashi', dst='Octavio Obregon'),
#  Row(src='Shinpei Kobayashi', dst='Sergei D. Odintsov'),
#  Row(src='Shinpei Kobayashi', dst=''),
#  Row(src='Shinpei Kobayashi', dst='Vladimir I.'),
#  Row(src='Kazuya Koyama', dst="Shin'ichi Nojiri"),
#  Row(src='Kazuya Koyama', dst='Octavio Obregon'),
#  Row(src='Kazuya Koyama', dst='Sergei D. Odintsov'),
#  Row(src='Kazuya Koyama', dst=''),
#  Row(src='Kazuya Koyama', dst='Vladimir I.'),
#  Row(src='Jiro Soda', dst="Shin'ichi Nojiri"),
#  Row(src='Jiro Soda', dst='Octavio Obregon'),
#  Row(src='Jiro Soda', dst='Sergei D. Odintsov'),
#  Row(src='Jiro Soda', dst=''),
#  Row(src='Jiro Soda', dst='Vladimir I.'),
#  Row(src='A. Ghosh', dst='Amit Ghosh'),
#  Row(src='P. Mitra', dst='Amit Ghosh'),
#  Row(src='Mohsen Alishahiha', dst='Shoibal Chakravarty'),
#  Row(src='Mohsen Alishahiha', dst='Keshav Dasgupta'),
#  Row(src='Mohsen Alishahiha', dst='Ori J. Ganor'),
#  Row(src='Mohsen Alishahiha', dst='Govindan Rajesh'),
#  Row(src='Yaron Oz', dst='Shoibal Chakravarty'),
#  Row(src='Yaron Oz', dst='Keshav Dasgupta'),
#  Row(src='Yaron Oz', dst='Ori J. Ganor'),
#  Row(src='Yaron Oz', dst='Govindan Rajesh'),
#  Row(src='M.M. Sheikh-Jabbari', dst='Shoibal Chakravarty'),
#  Row(src='M.M. Sheikh-Jabbari', dst='Keshav Dasgupta'),
#  Row(src='M.M. Sheikh-Jabbari', dst='Ori J. Ganor'),
#  Row(src='M.M. Sheikh-Jabbari', dst='Govindan Rajesh'),
#  Row(src='David Berenstein', dst='Yuji Sugawara'),
#  Row(src='Horatiu Nastase', dst='Yuji Sugawara'),
#  Row(src='David R. Morrison', dst='Constantin P. Bachas'),
#  Row(src='David R. Morrison', dst='Michael B. Green'),
#  Row(src='David R. Morrison', dst='Adam Schwimmer'),
#  Row(src='Nathan Seiberg', dst='Constantin P. Bachas'),
#  Row(src='Nathan Seiberg', dst='Michael B. Green'),
#  Row(src='Nathan Seiberg', dst='Adam Schwimmer'),
#  Row(src='Kazuo Fujikawa', dst='Rabin Banerjee'),
#  Row(src='Kazuo Fujikawa', dst='Sarmishtha Kumar'),
#  Row(src='Hiroaki Terashima (Department of Physics', dst='Rabin Banerjee'),
#  Row(src='Hiroaki Terashima (Department of Physics', dst='Sarmishtha Kumar'),
#  Row(src='', dst='Rabin Banerjee'),
#  Row(src='', dst='Sarmishtha Kumar'),
#  Row(src='Constantin Bachas', dst='O. Bergman (Harvard)'),
#  Row(src='Constantin Bachas', dst='A. Fayyazuddin (Harvard)'),
#  Row(src='Michael R. Douglas', dst='O. Bergman (Harvard)'),
#  Row(src='Michael R. Douglas', dst='A. Fayyazuddin (Harvard)'),
#  Row(src='Michael B. Green', dst='O. Bergman (Harvard)'),
#  Row(src='Michael B. Green', dst='A. Fayyazuddin (Harvard)'),
#  Row(src='Changhyun Ahn', dst='Radu Roiban'),
#  Row(src='Changhyun Ahn', dst='Radu Tatar'),
#  Row(src='Changhyun Ahn', dst='Johannes Walcher'),
#  Row(src='Stephen F. Hewson', dst='R. Manvelyan'),
#  Row(src='Stephen F. Hewson', dst='A. Melikyan'),
#  Row(src='Stephen F. Hewson', dst='R. Mkrtchyan'),
#  Row(src='Sheldon Katz', dst='Sheldon Katz'),
#  Row(src='Sheldon Katz', dst='Cumrun Vafa'),
#  Row(src='Cumrun Vafa', dst='Sheldon Katz'),
#  Row(src='Cumrun Vafa', dst='Cumrun Vafa'),
#  Row(src='Raphael Bousso (Stanford)', dst='H. Casini'),
#  Row(src='Igor B', dst='Igor B'),
#  Row(src='Igor B', dst='os'),
#  Row(src='os', dst='Igor B'),
#  Row(src='os', dst='os'),
#  Row(src='Dmitrij Sorokin', dst='Igor B'),
#  Row(src='Dmitrij Sorokin', dst='os'),
#  Row(src='Dmitrij Volkov', dst='Igor B'),
#  Row(src='Dmitrij Volkov', dst='os'),
#  Row(src='K. Intriligator', dst='S. Katz'),
#  Row(src='K. Intriligator', dst='P. Mayr'),
#  Row(src='K. Intriligator', dst='C. Vafa'),
#  Row(src='N. Seiberg', dst='S. Katz'),
#  Row(src='N. Seiberg', dst='P. Mayr'),
#  Row(src='N. Seiberg', dst='C. Vafa'),
#  Row(src='K. S. Viswanathan', dst='K. S. Viswanathan'),
#  Row(src='K. S. Viswanathan', dst='Yi Yang'),
#  Row(src='Y. Yang (Simon Fraser University)', dst='K. S. Viswanathan'),
#  Row(src='Y. Yang (Simon Fraser University)', dst='Yi Yang'),
#  Row(src='S.W. Hawking', dst='Per Kraus'),
#  Row(src='S.W. Hawking', dst='Finn Larsen'),
#  Row(src='S.W. Hawking', dst='Ruud Siebelink'),
#  Row(src='C.J. Hunter', dst='Per Kraus'),
#  Row(src='C.J. Hunter', dst='Finn Larsen'),
#  Row(src='C.J. Hunter', dst='Ruud Siebelink'),
#  Row(src='D.N. Page', dst='Per Kraus'),
#  Row(src='D.N. Page', dst='Finn Larsen'),
#  Row(src='D.N. Page', dst='Ruud Siebelink'),
#  Row(src='Jan de Boer', dst='S.Yamaguchi'),
#  Row(src='Jan de Boer', dst='Y.Ishimoto'),
#  Row(src='Jan de Boer', dst='K.Sugiyama (Kyoto Univ.)'),
#  Row(src='H. Lu', dst="Pietro Fr\\'e"),
#  Row(src='C.N. Pope', dst="Pietro Fr\\'e"),
#  Row(src='K.S. Stelle', dst="Pietro Fr\\'e"),
#  Row(src='Panagiota Kanti', dst='T. Multamaki'),
#  Row(src='Panagiota Kanti', dst='I. Vilja'),
#  Row(src='Richard Madden', dst='T. Multamaki'),
#  Row(src='Richard Madden', dst='I. Vilja'),
#  Row(src='Keith A. Olive', dst='T. Multamaki'),
#  Row(src='Keith A. Olive', dst='I. Vilja'),
#  Row(src='S.P. de Alwis', dst='J. Kluson'),
#  Row(src="Shin'ichi Nojiri", dst='V. D. Ivashchuk'),
#  Row(src="Shin'ichi Nojiri", dst='S.-W. Kim'),
#  Row(src='Sergei D. Odintsov', dst='V. D. Ivashchuk'),
#  Row(src='Sergei D. Odintsov', dst='S.-W. Kim'),
#  Row(src='Akikazu Hashimoto', dst='Kazuo Hosomichi'),
#  Row(src='Yeuk-Kwan E. Cheung', dst='Michael R. Douglas'),
#  Row(src='Ori J. Ganor', dst='Michael R. Douglas'),
#  Row(src='Morten Krogh', dst='Michael R. Douglas'),
#  Row(src='Andrei Yu.', dst='Michael R. Douglas'),
#  Row(src='Raphael Bousso (Stanford)', dst='Rong-Gen Cai'),
#  Row(src='Raphael Bousso (Stanford)', dst='Yun Soo Myung'),
#  Row(src='Elisabeth Kraus', dst='Dirk Kreimer'),
#  Row(src='Keshav Dasgupta', dst='J. X. Lu'),
#  Row(src='Keshav Dasgupta', dst='Shibaji Roy'),
#  Row(src='Sunil Mukhi', dst='J. X. Lu'),
#  Row(src='Sunil Mukhi', dst='Shibaji Roy'),
#  Row(src='Klaus Behrndt', dst='Klaus Behrndt'),
#  Row(src='Renata Kallosh', dst='Klaus Behrndt'),
#  Row(src='Joachim Rahmfeld', dst='Klaus Behrndt'),
#  Row(src='Marina Shmakova', dst='Klaus Behrndt'),
#  Row(src='', dst='Klaus Behrndt'),
#  Row(src='', dst='Klaus Behrndt'),
#  Row(src='Steven S. Gubser', dst='Davide Gaiotto'),
#  Row(src='Steven S. Gubser', dst='Nissan Itzhaki'),
#  Row(src='Steven S. Gubser', dst='Leonardo Rastelli'),
#  Row(src='Joseph Lykken', dst='Tianjun Li'),
#  Row(src='Lisa R', dst='Tianjun Li'),
#  Row(src='all', dst='Tianjun Li'),
#  Row(src='I. Antoniadis', dst='Andrea Gregori'),
#  Row(src='H. Partouche', dst='Andrea Gregori'),
#  Row(src='T.R. Taylor', dst='Andrea Gregori'),
#  Row(src='Eric Bergshoeff', dst='S. Groot Nibbelink'),
#  Row(src='Eric Bergshoeff', dst='H.P. Nilles'),
#  Row(src='Eric Bergshoeff', dst='M. Olechowski'),
#  Row(src='Renata Kallosh', dst='S. Groot Nibbelink'),
#  Row(src='Renata Kallosh', dst='H.P. Nilles'),
#  Row(src='Renata Kallosh', dst='M. Olechowski'),
#  Row(src='Antoine Van Proeyen', dst='S. Groot Nibbelink'),
#  Row(src='Antoine Van Proeyen', dst='H.P. Nilles'),
#  Row(src='Antoine Van Proeyen', dst='M. Olechowski'),
#  Row(src='Keshav Dasgupta', dst='Alok Kumar'),
#  Row(src='Keshav Dasgupta', dst='Aalok Misra'),
#  Row(src='Sunil Mukhi', dst='Alok Kumar'),
#  Row(src='Sunil Mukhi', dst='Aalok Misra'),
#  Row(src='John Madore', dst='Jesper M. Grimstrup (Vienna)'),
#  Row(src='John Madore', dst='Raimar Wulkenhaar (Leipzig)'),
#  Row(src='Stefan Schraml', dst='Jesper M. Grimstrup (Vienna)'),
#  Row(src='Stefan Schraml', dst='Raimar Wulkenhaar (Leipzig)'),
#  Row(src='Peter Schupp', dst='Jesper M. Grimstrup (Vienna)'),
#  Row(src='Peter Schupp', dst='Raimar Wulkenhaar (Leipzig)'),
#  Row(src='Julius Wess', dst='Jesper M. Grimstrup (Vienna)'),
#  Row(src='Julius Wess', dst='Raimar Wulkenhaar (Leipzig)'),
#  Row(src='Andreas Br', dst='Carlos Nunez (Harvard U.)'),
#  Row(src='Andreas Br', dst='I. Y. Park (Texas A&M)'),
#  Row(src='Andreas Br', dst='Martin Schvellinger'),
#  Row(src='huber', dst='Carlos Nunez (Harvard U.)'),
#  Row(src='huber', dst='I. Y. Park (Texas A&M)'),
#  Row(src='huber', dst='Martin Schvellinger'),
#  Row(src='Yaron Oz', dst='Carlos Nunez (Harvard U.)'),
#  Row(src='Yaron Oz', dst='I. Y. Park (Texas A&M)'),
#  Row(src='Yaron Oz', dst='Martin Schvellinger'),
#  Row(src='Andre Lukas', dst='Ruth Gregory'),
#  Row(src='Andre Lukas', dst='Antonio Padilla'),
#  Row(src='Burt A. Ovrut', dst='Ruth Gregory'),
#  Row(src='Burt A. Ovrut', dst='Antonio Padilla'),
#  Row(src='K. S. Stelle', dst='Ruth Gregory'),
#  Row(src='K. S. Stelle', dst='Antonio Padilla'),
#  Row(src='Daniel Waldram', dst='Ruth Gregory'),
#  Row(src='Daniel Waldram', dst='Antonio Padilla'),
#  Row(src='H. Kawai', dst='Ivan K. Kostov'),
#  Row(src='N. Kawamoto', dst='Ivan K. Kostov'),
#  Row(src='T. Mogami', dst='Ivan K. Kostov'),
#  Row(src='Y. Watabiki', dst='Ivan K. Kostov'),
#  Row(src='Ron Donagi', dst='Takahiro Masuda'),
#  Row(src='Ron Donagi', dst='Toru Sasaki'),
#  Row(src='Ron Donagi', dst='Hisao Suzuki (Hokkaido University)'),
#  Row(src='Edward Witten', dst='Takahiro Masuda'),
#  Row(src='Edward Witten', dst='Toru Sasaki'),
#  Row(src='Edward Witten', dst='Hisao Suzuki (Hokkaido University)'),
#  Row(src='Peter van Nieuwenhuizen', dst='Matthias Blau'),
#  Row(src='Peter van Nieuwenhuizen', dst='George Thompson'),
#  Row(src='Andrew Waldron (ITP S.U.N.Y. Stony Brook)', dst='Matthias Blau'),
#  Row(src='Andrew Waldron (ITP S.U.N.Y. Stony Brook)', dst='George Thompson'),
#  Row(src='Steven S. Gubser', dst='Anna Ceresole'),
#  Row(src='Steven S. Gubser', dst="Gianguido Dall'Agata"),
#  Row(src='Steven S. Gubser', dst="Riccardo D'Auria"),
#  Row(src='N.P. Warner', dst='Luuk Hoevenaars'),
#  Row(src='D. Sorokin', dst='E. Ivanov'),
#  Row(src='D. Sorokin', dst='E. Sokatchev'),
#  Row(src='M. Tonin', dst='E. Ivanov'),
#  Row(src='M. Tonin', dst='E. Sokatchev'),
#  Row(src='N. Seiberg', dst='Y. M. Cho'),
#  Row(src='N. Seiberg', dst='D. G. Pak'),
#  Row(src='E. Witten', dst='Y. M. Cho'),
#  Row(src='E. Witten', dst='D. G. Pak'),
#  Row(src='Mike A. Clayton', dst='Anirban Basu'),
#  Row(src='Mike A. Clayton', dst='Satish D.Joglekar (I.I.T.Kanpur'),
#  Row(src='Mike A. Clayton', dst='India)'),
#  Row(src='H. Aoki', dst='J. Ambjorn'),
#  Row(src='H. Aoki', dst='K. N. Anagnostopoulos'),
#  Row(src='H. Aoki', dst='W. Bietenholz'),
#  Row(src='H. Aoki', dst='T. Hotta'),
#  Row(src='H. Aoki', dst='J.'),
#  Row(src='S. Iso', dst='J. Ambjorn'),
#  Row(src='S. Iso', dst='K. N. Anagnostopoulos'),
#  Row(src='S. Iso', dst='W. Bietenholz'),
#  Row(src='S. Iso', dst='T. Hotta'),
#  Row(src='S. Iso', dst='J.'),
#  Row(src='H. Kawai', dst='J. Ambjorn'),
#  Row(src='H. Kawai', dst='K. N. Anagnostopoulos'),
#  Row(src='H. Kawai', dst='W. Bietenholz'),
#  Row(src='H. Kawai', dst='T. Hotta'),
#  Row(src='H. Kawai', dst='J.'),
#  Row(src='Y. Kitazawa', dst='J. Ambjorn'),
#  Row(src='Y. Kitazawa', dst='K. N. Anagnostopoulos'),
#  Row(src='Y. Kitazawa', dst='W. Bietenholz'),
#  Row(src='Y. Kitazawa', dst='T. Hotta'),
#  Row(src='Y. Kitazawa', dst='J.'),
#  Row(src='T. Tada', dst='J. Ambjorn'),
#  Row(src='T. Tada', dst='K. N. Anagnostopoulos'),
#  Row(src='T. Tada', dst='W. Bietenholz'),
#  Row(src='T. Tada', dst='T. Hotta'),
#  Row(src='T. Tada', dst='J.'),
#  Row(src='Jean-Marc DAUL', dst='J. P. Nunes'),
#  Row(src='Jean-Marc DAUL', dst='H. J. Schnitzer'),
#  Row(src='Vladimir A.KAZAKOV', dst='J. P. Nunes'),
#  Row(src='Vladimir A.KAZAKOV', dst='H. J. Schnitzer'),
#  Row(src='J. Berges', dst='Ken-Ichi Aoki (Kanazawa U.)'),
#  Row(src='J. Berges', dst='Keiichi Morikawa (Kanazawa U.)'),
#  Row(src='J. Berges', dst='Jun-Ichi'),
#  Row(src='C. Wetterich', dst='Ken-Ichi Aoki (Kanazawa U.)'),
#  Row(src='C. Wetterich', dst='Keiichi Morikawa (Kanazawa U.)'),
#  Row(src='C. Wetterich', dst='Jun-Ichi'),
#  Row(src='Ralph Blumenhagen', dst='Ralph Blumenhagen'),
#  Row(src='Ralph Blumenhagen', dst='Lars Goerlich'),
#  Row(src='Ralph Blumenhagen', dst='Tassilo Ott'),
#  Row(src='Boris Kors', dst='Ralph Blumenhagen'),
#  Row(src='Boris Kors', dst='Lars Goerlich'),
#  Row(src='Boris Kors', dst='Tassilo Ott'),
#  Row(src='Dieter Lust', dst='Ralph Blumenhagen'),
#  Row(src='Dieter Lust', dst='Lars Goerlich'),
#  Row(src='Dieter Lust', dst='Tassilo Ott'),
#  Row(src='', dst='Ralph Blumenhagen'),
#  Row(src='', dst='Lars Goerlich'),
#  Row(src='', dst='Tassilo Ott'),
#  Row(src='Tassilo Ott (Humboldt', dst='Ralph Blumenhagen'),
#  Row(src='Tassilo Ott (Humboldt', dst='Lars Goerlich'),
#  Row(src='Tassilo Ott (Humboldt', dst='Tassilo Ott'),
#  Row(src='Yuji Igarashi', dst='Yuji Igarashi'),
#  Row(src='Yuji Igarashi', dst='Katsumi Itoh'),
#  Row(src='Yuji Igarashi', dst='Hiroto So'),
#  Row(src='Katsumi Itoh', dst='Yuji Igarashi'),
#  Row(src='Katsumi Itoh', dst='Katsumi Itoh'),
#  Row(src='Katsumi Itoh', dst='Hiroto So'),
#  Row(src='Hiroto So', dst='Yuji Igarashi'),
#  Row(src='Hiroto So', dst='Katsumi Itoh'),
#  Row(src='Hiroto So', dst='Hiroto So'),
#  Row(src='M. Bershadsky', dst='A.Gorsky'),
#  Row(src='M. Bershadsky', dst='S.Gukov'),
#  Row(src='M. Bershadsky', dst='A.Mironov'),
#  Row(src='V. Sadov', dst='A.Gorsky'),
#  Row(src='V. Sadov', dst='S.Gukov'),
#  Row(src='V. Sadov', dst='A.Mironov'),
#  Row(src='C. Vafa', dst='A.Gorsky'),
#  Row(src='C. Vafa', dst='S.Gukov'),
#  Row(src='C. Vafa', dst='A.Mironov'),
#  Row(src='Klaus Behrndt', dst='M. Cvetic'),
#  Row(src='Carl Herrmann', dst='M. Cvetic'),
#  Row(src='Jan Louis', dst='M. Cvetic'),
#  Row(src='Steven Thomas', dst='M. Cvetic'),
#  Row(src='P. Pouliot', dst='Matthew J. Strassler (IAS)'),
#  Row(src='M.J. Strassler (Rutgers University)', dst='Matthew J. Strassler (IAS)'),
#  Row(src='Ernest Baver', dst='Alex'),
#  Row(src='Ernest Baver', dst='er Berkovich'),
#  Row(src='Ernest Baver', dst='Barry M. McCoy'),
#  Row(src='Ernest Baver', dst='Anne Schilling'),
#  Row(src='Doron Gepner', dst='Alex'),
#  Row(src='Doron Gepner', dst='er Berkovich'),
#  Row(src='Doron Gepner', dst='Barry M. McCoy'),
#  Row(src='Doron Gepner', dst='Anne Schilling'),
#  Row(src='I. Antoniadis', dst='Matthias Klein'),
#  Row(src='C. Bachas', dst='Matthias Klein'),
#  Row(src='E. Dudas', dst='Matthias Klein'),
#  Row(src='Oleg Lunin', dst='Oleg Lunin'),
#  Row(src='Oleg Lunin', dst='Samir D. Mathur'),
#  Row(src='Oleg Lunin', dst='I.Y. Park'),
#  Row(src='Oleg Lunin', dst='Ashish Saxena'),
#  Row(src='Juan Maldacena', dst='Oleg Lunin'),
#  Row(src='Juan Maldacena', dst='Samir D. Mathur'),
#  Row(src='Juan Maldacena', dst='I.Y. Park'),
#  Row(src='Juan Maldacena', dst='Ashish Saxena'),
#  Row(src='Liat Maoz', dst='Oleg Lunin'),
#  Row(src='Liat Maoz', dst='Samir D. Mathur'),
#  Row(src='Liat Maoz', dst='I.Y. Park'),
#  Row(src='Liat Maoz', dst='Ashish Saxena'),
#  Row(src='Silvia Penati', dst='S. Penati'),
#  Row(src='Silvia Penati', dst='A. Refolli'),
#  Row(src='Silvia Penati', dst='D. Zanon'),
#  Row(src='Andrea Refolli', dst='S. Penati'),
#  Row(src='Andrea Refolli', dst='A. Refolli'),
#  Row(src='Andrea Refolli', dst='D. Zanon'),
#  Row(src='Daniela Zanon', dst='S. Penati'),
#  Row(src='Daniela Zanon', dst='A. Refolli'),
#  Row(src='Daniela Zanon', dst='D. Zanon'),
#  Row(src='L. Cornalba (IHES)', dst='Seiji Terashima'),
#  Row(src='N. Seiberg', dst='Andrei Lossev'),
#  Row(src='N. Seiberg', dst='Nikita Nekrassov'),
#  Row(src='N. Seiberg', dst='Samson Shatashvili'),
#  Row(src='E. Witten', dst='Andrei Lossev'),
#  Row(src='E. Witten', dst='Nikita Nekrassov'),
#  Row(src='E. Witten', dst='Samson Shatashvili'),
#  Row(src='Thibault Damour', dst='Marc Henneaux'),
#  Row(src='Thibault Damour', dst='Bernard Julia'),
#  Row(src='Marc Henneaux', dst='Marc Henneaux'),
#  Row(src='Marc Henneaux', dst='Bernard Julia'),
#  Row(src='Bernard Julia', dst='Marc Henneaux'),
#  Row(src='Bernard Julia', dst='Bernard Julia'),
#  Row(src='Hermann Nicolai', dst='Marc Henneaux'),
#  Row(src='Hermann Nicolai', dst='Bernard Julia'),
#  Row(src='A.I. Davydychev', dst='A.I. Davydychev'),
#  Row(src='A.I. Davydychev', dst='M.Yu. Kalmykov'),
#  Row(src='R. Delbourgo', dst='A.I. Davydychev'),
#  Row(src='R. Delbourgo', dst='M.Yu. Kalmykov'),
#  Row(src='Werner Krauth', dst='J.F. Wheater'),
#  Row(src='Werner Krauth', dst='G. Vernizzi'),
#  Row(src='Matthias Staudacher', dst='J.F. Wheater'),
#  Row(src='Matthias Staudacher', dst='G. Vernizzi'),
#  Row(src='J. Ambj{\\o}rn', dst='P.Wiegmann'),
#  Row(src='J. Ambj{\\o}rn', dst='A.Zabrodin'),
#  Row(src='L. Chekhov', dst='P.Wiegmann'),
#  Row(src='L. Chekhov', dst='A.Zabrodin'),
#  Row(src='C.F. Kristjansen', dst='P.Wiegmann'),
#  Row(src='C.F. Kristjansen', dst='A.Zabrodin'),
#  Row(src='Yu. Makeenko', dst='P.Wiegmann'),
#  Row(src='Yu. Makeenko', dst='A.Zabrodin'),
#  Row(src='J.L.F. Barbon', dst='L. Alvarez-Gaume'),
#  Row(src='J.L.F. Barbon', dst='J.L.F. Barbon'),
#  Row(src='E. Rabinovici', dst='L. Alvarez-Gaume'),
#  Row(src='E. Rabinovici', dst='J.L.F. Barbon'),
#  Row(src='Mirjam Cvetic', dst='Alon E. Faraggi'),
#  Row(src='Gary Shiu', dst='Alon E. Faraggi'),
#  Row(src='Angel M. Uranga', dst='Alon E. Faraggi'),
#  Row(src='David R. Morrison', dst='Kazutoshi Ohta'),
#  Row(src='David R. Morrison', dst='Takashi Yokono'),
#  Row(src='M. Ronen Plesser', dst='Kazutoshi Ohta'),
#  Row(src='M. Ronen Plesser', dst='Takashi Yokono'),
#  Row(src='J.K. Erickson', dst='Chanju Kim'),
#  Row(src='J.K. Erickson', dst='Kimyeong Lee'),
#  Row(src='J.K. Erickson', dst=''),
#  Row(src='J.K. Erickson', dst='Piljin Yi'),
#  Row(src='G.W. Semenoff', dst='Chanju Kim'),
#  Row(src='G.W. Semenoff', dst='Kimyeong Lee'),
#  Row(src='G.W. Semenoff', dst=''),
#  Row(src='G.W. Semenoff', dst='Piljin Yi'),
#  Row(src='K. Zarembo', dst='Chanju Kim'),
#  Row(src='K. Zarembo', dst='Kimyeong Lee'),
#  Row(src='K. Zarembo', dst=''),
#  Row(src='K. Zarembo', dst='Piljin Yi'),
#  Row(src='N. Chair', dst='Ken-ji Hamada'),
#  Row(src='N. Chair', dst='Hiroshi Ishikawa'),
#  Row(src='V.K. Dobrev', dst='Ken-ji Hamada'),
#  Row(src='V.K. Dobrev', dst='Hiroshi Ishikawa'),
#  Row(src='H. Kanno', dst='Ken-ji Hamada'),
#  Row(src='H. Kanno', dst='Hiroshi Ishikawa'),
#  Row(src='C.M. Hull', dst='Carlos Herdeiro'),
#  Row(src='C.M. Hull', dst='Shinji Hirano'),
#  Row(src='C.M. Hull', dst='Renata Kallosh (Stanford U.)'),
#  Row(src='G. Grignani', dst='C.R. Gattringer'),
#  Row(src='G. Grignani', dst='L.D. Paniak'),
#  Row(src='G. Grignani', dst='G.W. Semenoff (University of British'),
#  Row(src='G. Semenoff', dst='C.R. Gattringer'),
#  Row(src='G. Semenoff', dst='L.D. Paniak'),
#  Row(src='G. Semenoff', dst='G.W. Semenoff (University of British'),
#  Row(src='P. Sodano', dst='C.R. Gattringer'),
#  Row(src='P. Sodano', dst='L.D. Paniak'),
#  Row(src='P. Sodano', dst='G.W. Semenoff (University of British'),
#  Row(src='O. Tirkkonen', dst='C.R. Gattringer'),
#  Row(src='O. Tirkkonen', dst='L.D. Paniak'),
#  Row(src='O. Tirkkonen', dst='G.W. Semenoff (University of British'),
#  Row(src='Takeshi Sato', dst='Igor B'),
#  Row(src='Takeshi Sato', dst='os'),
#  Row(src='Takeshi Sato', dst='Wolfgang Kummer'),
#  Row(src='R. A. Janik (1', dst='Daniel Kabat'),
#  Row(src='R. A. Janik (1', dst='Gilad Lifschytz'),
#  Row(src='R. A. Janik (1', dst='David A. Lowe'),
#  Row(src='2)', dst='Daniel Kabat'),
#  Row(src='2)', dst='Gilad Lifschytz'),
#  Row(src='2)', dst='David A. Lowe'),
#  Row(src='J. Wosiek (2) ((1) CEA-Saclay', dst='Daniel Kabat'),
#  Row(src='J. Wosiek (2) ((1) CEA-Saclay', dst='Gilad Lifschytz'),
#  Row(src='J. Wosiek (2) ((1) CEA-Saclay', dst='David A. Lowe'),
#  Row(src='(2)', dst='Daniel Kabat'),
#  Row(src='(2)', dst='Gilad Lifschytz'),
#  Row(src='(2)', dst='David A. Lowe'),
#  Row(src='F. Bastianelli', dst='Fiorenzo Bastianelli'),
#  ...]

# %% [markdown]
# # Classifier

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.sql.types import FloatType
import numpy as np 


custom_udf_schema = VectorUDT()
def to_sparse_(v):
    
    if isinstance(v, SparseVector):
        return v
    vs = np.array([v], dtype=np.float64)
    nonzero = np.nonzero(vs)[0]
    return SparseVector(len(vs), nonzero, vs[nonzero])

to_sparse = udf(to_sparse_, custom_udf_schema)

zou.show()

zou2 = zou.withColumn('inDegree2', to_sparse(zou.inDegree))
zou3 = zou2.withColumn('cites', zou2['cites'].cast(FloatType()))

(train, test) = zou3.rdd.randomSplit([0.8, 0.2])

clf = LogisticRegression(featuresCol="inDegree2", labelCol="cites", predictionCol="pred", rawPredictionCol="raw_pred", maxIter=10)


model = clf.fit(train.toDF())
result = model.transform(test.toDF())

print("Prediction Output :")
print(result.head(1))
# Out:
# +-----+-------+-----+--------+-----+----+--------------------+--------------------+-----+--------------------+
# |  src|    dst|cites|inDegree|   id|year|              topics|             authors|temp1|                text|
# +-----+-------+-----+--------+-----+----+--------------------+--------------------+-----+--------------------+
# |10009|9701020|    0|      15|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|9305185|    0|     180|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|   8224|    0|      15|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|   8197|    0|      15|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|   4177|    0|      14|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|9311189|    0|      37|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|9701117|    0|      20|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|9912265|    1|      13|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|   5206|    0|      17|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10010| 107263|    0|      12|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|   2159|    1|     109|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9610006|    0|      20|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9605053|    1|     110|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9707176|    1|      51|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9906070|    1|     126|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9711200|    1|    2307|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9506101|    1|      70|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9712230|    1|     111|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|   6204|    1|      35|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9803262|    0|      18|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# +-----+-------+-----+--------+-----+----+--------------------+--------------------+-----+--------------------+
# only showing top 20 rows
# Prediction Output :
# ERROR:root:KeyboardInterrupt while sending command.                 (0 + 1) / 1]
# Traceback (most recent call last):
#   File "/opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/clientserver.py", line 475, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/flo/dssp/15-challenge/work.ipynb Cell 16' in <cell line: 31>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/flo/dssp/15-challenge/work.ipynb#ch0000019vscode-remote?line=27'>28</a> result = model.transform(test.toDF())
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/flo/dssp/15-challenge/work.ipynb#ch0000019vscode-remote?line=29'>30</a> print("Prediction Output :")
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/flo/dssp/15-challenge/work.ipynb#ch0000019vscode-remote?line=30'>31</a> print(result.head(1))
#
# File /opt/spark/python/pyspark/sql/dataframe.py:1605, in DataFrame.head(self, n)
#    <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=1602'>1603</a>     rs = self.head(1)
#    <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=1603'>1604</a>     return rs[0] if rs else None
# -> <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=1604'>1605</a> return self.take(n)
#
# File /opt/spark/python/pyspark/sql/dataframe.py:744, in DataFrame.take(self, num)
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=733'>734</a> def take(self, num):
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=734'>735</a>     """Returns the first ``num`` rows as a :class:`list` of :class:`Row`.
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=735'>736</a>
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=736'>737</a>     .. versionadded:: 1.3.0
#    (...)
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=741'>742</a>     [Row(age=2, name='Alice'), Row(age=5, name='Bob')]
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=742'>743</a>     """
# --> <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=743'>744</a>     return self.limit(num).collect()
#
# File /opt/spark/python/pyspark/sql/dataframe.py:693, in DataFrame.collect(self)
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=682'>683</a> """Returns all the records as a list of :class:`Row`.
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=683'>684</a>
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=684'>685</a> .. versionadded:: 1.3.0
#    (...)
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=689'>690</a> [Row(age=2, name='Alice'), Row(age=5, name='Bob')]
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=690'>691</a> """
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=691'>692</a> with SCCallSiteSync(self._sc) as css:
# --> <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=692'>693</a>     sock_info = self._jdf.collectToPython()
#     <a href='file:///opt/spark/python/pyspark/sql/dataframe.py?line=693'>694</a> return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#
# File /opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py:1320, in JavaMember.__call__(self, *args)
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1312'>1313</a> args_command, temp_args = self._build_args(*args)
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1314'>1315</a> command = proto.CALL_COMMAND_NAME +\
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1315'>1316</a>     self.command_header +\
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1316'>1317</a>     args_command +\
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1317'>1318</a>     proto.END_COMMAND_PART
# -> <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1319'>1320</a> answer = self.gateway_client.send_command(command)
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1320'>1321</a> return_value = get_return_value(
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1321'>1322</a>     answer, self.gateway_client, self.target_id, self.name)
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1323'>1324</a> for temp_arg in temp_args:
#
# File /opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1035'>1036</a> connection = self._get_connection()
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1036'>1037</a> try:
# -> <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1037'>1038</a>     response = connection.send_command(command)
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1038'>1039</a>     if binary:
#    <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/java_gateway.py?line=1039'>1040</a>         return response, self._create_connection_guard(connection)
#
# File /opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/clientserver.py:475, in ClientServerConnection.send_command(self, command)
#     <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/clientserver.py?line=472'>473</a> try:
#     <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/clientserver.py?line=473'>474</a>     while True:
# --> <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/clientserver.py?line=474'>475</a>         answer = smart_decode(self.stream.readline()[:-1])
#     <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/clientserver.py?line=475'>476</a>         logger.debug("Answer received: {0}".format(answer))
#     <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/clientserver.py?line=476'>477</a>         # Happens when a the other end is dead. There might be an empty
#     <a href='file:///opt/spark/python/lib/py4j-0.10.9.3-src.zip/py4j/clientserver.py?line=477'>478</a>         # answer before the socket raises an error.
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     <a href='file:///usr/lib/python3.8/socket.py?line=666'>667</a> while True:
#     <a href='file:///usr/lib/python3.8/socket.py?line=667'>668</a>     try:
# --> <a href='file:///usr/lib/python3.8/socket.py?line=668'>669</a>         return self._sock.recv_into(b)
#     <a href='file:///usr/lib/python3.8/socket.py?line=669'>670</a>     except timeout:
#     <a href='file:///usr/lib/python3.8/socket.py?line=670'>671</a>         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
zou.show()
# Out:
# +-------+-------+-----+--------+
# |    src|    dst|cites|inDegree|
# +-------+-------+-----+--------+
# |9510123|9502114|    1|      20|
# |9707075|9604178|    1|     132|
# |9312155|9506142|    0|       8|
# |9911255| 302165|    0|      12|
# |9701033| 209076|    0|      12|
# |9710020|9709228|    1|      21|
# |9901042|9510135|    1|     737|
# | 209146|9502077|    0|      70|
# |9705079|9702201|    1|      81|
# |   3016|9207067|    0|      46|
# |9402099| 105041|    0|      13|
# |9705061|9503216|    1|      10|
# | 109090|   9107|    0|      14|
# | 107016|9304156|    0|      17|
# |9812004|9212092|    0|      15|
# |9401058|9511114|    0|      12|
# |  12261| 202126|    0|      30|
# | 207246|9807137|    1|      85|
# |9501144|9311081|    1|      54|
# |9304048|9510008|    0|      28|
# +-------+-------+-----+--------+
# only showing top 20 rows

# %%
def get_authors(edges, nodes):
    
    edges_authors_src = edges.join(nodes, edges.src == nodes.id, ).drop(nodes.)
    # edges_authors_dst = edges_authors_src.join(nodes, edges.dst == nodes.id)

    return edges_authors_src

# %%
zou.show()
# Out:
# +-----+-------+-----+--------+-----+----+--------------------+--------------------+-----+--------------------+
# |  src|    dst|cites|inDegree|   id|year|              topics|             authors|temp1|                text|
# +-----+-------+-----+--------+-----+----+--------------------+--------------------+-----+--------------------+
# |10009|9701020|    0|      15|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|9305185|    0|     180|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|   8224|    0|      15|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|   8197|    0|      15|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|   4177|    0|      14|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|9311189|    0|      37|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|9701117|    0|      20|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|9912265|    1|      13|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10009|   5206|    0|      17|10009|2000|normalized weyl-t...|       Takuya Masuda| null|we define a norma...|
# |10010| 107263|    0|      12|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|   2159|    1|     109|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9610006|    0|      20|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9605053|    1|     110|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9707176|    1|      51|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9906070|    1|     126|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9711200|    1|    2307|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9506101|    1|      70|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9712230|    1|     111|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|   6204|    1|      35|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# |10010|9803262|    0|      18|10010|2000|supersymmetry and...|Steven S. Gubser ...| null|three-form flux i...|
# +-----+-------+-----+--------+-----+----+--------------------+--------------------+-----+--------------------+
# only showing top 20 rows
